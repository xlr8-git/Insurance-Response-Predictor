# %% [markdown]
# # Vehicle Insurance Response Prediction

# %% [markdown]
# ## Importing the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the data set

# %%
vehicle_insurance_df = pd.read_csv(r"/home/xlr8/ml,dl,nlp,llm,genai,cv/ML-App5-Insurance-Response-Predictor-AI-App/archive/train.csv")

# %%
vehicle_insurance_df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
vehicle_insurance_df.tail()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 381104    1-2 Year             No         30170.0                  26.0
# 381105    < 1 Year             No         40016.0                 152.0
# 381106    < 1 Year             No         35118.0                 160.0
# 381107   > 2 Years            Yes         44617.0                 124.0
# 381108    1-2 Year             No         41777.0                  26.0
#
#         Vintage  Response
# 381104       88         0
# 381105      131         0
# 381106      161         0
# 381107       74         0
# 381108      237         0

# %%
vehicle_insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
vehicle_insurance_df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
vehicle_insurance_df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
vehicle_insurance_df['Response'].value_counts()
# Out:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
vehicle_insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

numerical_cols = ['Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 
                  'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'Response']

# %%
for col in numerical_cols:
    plt.figure(figsize=(8,5))
    sns.histplot(vehicle_insurance_df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(x='Vehicle_Damage', y=col, data=vehicle_insurance_df)
    plt.title(f"{col} vs Vehicle Damage")
    plt.xlabel("Vehicle Damage")
    plt.ylabel(col)
    plt.show()

# %%
plt.figure(figsize=(10,8))
corr = vehicle_insurance_df[numerical_cols].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
vehicle_insurance_df['Gender'] = LabelEncoder().fit_transform(vehicle_insurance_df['Gender'])

# %%
vehicle_insurance_df['Vehicle_Damage'] = LabelEncoder().fit_transform(vehicle_insurance_df['Vehicle_Damage'])

# %%
vehicle_insurance_df['Gender'].value_counts()
# Out:
# Gender
# 1    206089
# 0    175020
# Name: count, dtype: int64

# %%
vehicle_insurance_df['Vehicle_Damage'].value_counts()
# Out:
# Vehicle_Damage
# 1    192413
# 0    188696
# Name: count, dtype: int64

# %%
dummy_vehicle_age = pd.get_dummies(vehicle_insurance_df['Vehicle_Age'], prefix='Age', prefix_sep='_')

# %%
vehicle_insurance_df = pd.concat([vehicle_insurance_df, dummy_vehicle_age], axis=1)

# %%
vehicle_insurance_df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1         28.0                   0
# 1   2       1   76                1          3.0                   0
# 2   3       1   47                1         28.0                   0
# 3   4       1   21                1         11.0                   1
# 4   5       0   29                1         41.0                   1
#
#   Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years               1         40454.0                  26.0      217
# 1    1-2 Year               0         33536.0                  26.0      183
# 2   > 2 Years               1         38294.0                  26.0       27
# 3    < 1 Year               0         28619.0                 152.0      203
# 4    < 1 Year               0         27496.0                 152.0       39
#
#    Response  Age_1-2 Year  Age_< 1 Year  Age_> 2 Years
# 0         1         False         False           True
# 1         0          True         False          False
# 2         1         False         False           True
# 3         0         False          True          False
# 4         0         False          True          False

# %%
vehicle_insurance_df.drop(['id', 'Vehicle_Age', 'Age_1-2 Year'], axis=1, inplace=True)

# %%
vehicle_insurance_df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       1   44                1         28.0                   0
# 1       1   76                1          3.0                   0
# 2       1   47                1         28.0                   0
# 3       1   21                1         11.0                   1
# 4       0   29                1         41.0                   1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0               1         40454.0                  26.0      217         1
# 1               0         33536.0                  26.0      183         0
# 2               1         38294.0                  26.0       27         1
# 3               0         28619.0                 152.0      203         0
# 4               0         27496.0                 152.0       39         0
#
#    Age_< 1 Year  Age_> 2 Years
# 0         False           True
# 1         False          False
# 2         False           True
# 3          True          False
# 4          True          False

# %%
X = vehicle_insurance_df.drop('Response', axis=1)
y = vehicle_insurance_df['Response']

# %%
yesResponse = vehicle_insurance_df[vehicle_insurance_df['Response'] == 1]
noResponse = vehicle_insurance_df[vehicle_insurance_df['Response'] == 0]

# %%
print(yesResponse.shape, noResponse.shape)
# Out:
# (46710, 12) (334399, 12)

# %%
from imblearn.under_sampling import NearMiss

# %%
from imblearn.combine import SMOTETomek

smk = SMOTETomek(random_state=42)
X_res, y_res = smk.fit_resample(X, y)

# %%
print(X_res.shape, y_res.shape)
# Out:
# (652380, 11) (652380,)

# %%
from collections import Counter
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_res)))
# Out:
# Original dataset shape Counter({0: 334399, 1: 46710})
# Resampled dataset shape Counter({1: 326190, 0: 326190})

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (456666, 11) (195714, 11)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (456666,) (195714,)

# %%
plt.figure(figsize=(20, 8))
heatmap = sns.heatmap(vehicle_insurance_df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# ## Building ML Models

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dt_clf = DecisionTreeClassifier()

# %%
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_preds_dt = dt_clf.predict(X_test)

# %%
print("Accuracy Score of the Decision Tree Model", accuracy_score(y_test, y_preds_dt))
# Out:
# Accuracy Score of the Decision Tree Model 0.8792830354496868

# %%
print("ROC AUC Score of the Decision Tree Model", roc_auc_score(y_test, y_preds_dt))
# Out:
# ROC AUC Score of the Decision Tree Model 0.8792844900130908

# %%
#Confusion Matrix of Decision Tree Model.
cm = confusion_matrix(y_test, y_preds_dt)

x_axis_labels = ["Yes", "No"]
y_axis_labels = ["Yes", "No"]

f, ax = plt.subplots(figsize =(10,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Greens", 
            xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Model')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Decision Tree Model')

# %% [markdown]
# ### Ensemble Models

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier, AdaBoostClassifier

# %%
rf_clf = RandomForestClassifier(n_estimators=10)
bg_clf = BaggingClassifier(n_estimators=10)
ada_clf = AdaBoostClassifier(n_estimators=10)

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
bg_clf.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=10)

# %%
y_preds_rf = rf_clf.predict(X_test) 
y_preds_bg = bg_clf.predict(X_test) 
y_preds_ada = ada_clf.predict(X_test)

# %%
print("Accuracy Score of the Random Forest Model", accuracy_score(y_test, y_preds_rf))
print("Accuracy Score of the Bagging Classifier Model", accuracy_score(y_test, y_preds_bg))
print("Accuracy Score of the AdaBoost Classifier Model", accuracy_score(y_test, y_preds_ada))
# Out:
# Accuracy Score of the Random Forest Model 0.880769898934159
# Accuracy Score of the Bagging Classifier Model 0.8971356162563741
# Accuracy Score of the AdaBoost Classifier Model 0.779050042408821

# %%
print("ROC AUC Score of the Random Forest Model", roc_auc_score(y_test, y_preds_rf))
print("ROC AUC Score of the Bagging Classifier Model", roc_auc_score(y_test, y_preds_bg))
print("ROC AUC Score of the AdaBoost Classifier Model", roc_auc_score(y_test, y_preds_ada))
# Out:
# ROC AUC Score of the Random Forest Model 0.8807702567424572
# ROC AUC Score of the Bagging Classifier Model 0.8971334398418795
# ROC AUC Score of the AdaBoost Classifier Model 0.7790838629684024

# %%
#Confusion Matrix of Random Forest Classifier Model.
cm = confusion_matrix(y_test, y_preds_rf)

x_axis_labels = ["Yes", "No"]
y_axis_labels = ["Yes", "No"]

f, ax = plt.subplots(figsize =(10,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Greens", 
            xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Random Forest Classifier Model')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Random Forest Classifier Model')

# %%
#Confusion Matrix of Bagging Classifier Model.
cm = confusion_matrix(y_test, y_preds_bg)

x_axis_labels = ["Yes", "No"]
y_axis_labels = ["Yes", "No"]

f, ax = plt.subplots(figsize =(10,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Greens", 
            xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Bagging Classifier Model')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Bagging Classifier Model')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

param_grid = {
    'n_estimators': [2,3,4,5],       
    'max_depth': [3,4,5],    
    'min_samples_split': [2, 5],      
    'min_samples_leaf': [2, 4],      
    'max_features': ['sqrt', 'log2'] 
}

rf_clf = RandomForestClassifier(random_state=42)

# %%
grid_search = GridSearchCV(estimator=rf_clf,
                           param_grid=param_grid,
                           cv=3,              
                           n_jobs=-1,        
                           verbose=2,
                           scoring='accuracy')

grid_search.fit(X_train, y_train)

print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   4.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   3.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   3.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   2.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   3.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   4.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   3.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   4.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   3.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   4.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   3.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   3.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   5.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   3.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   7.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   7.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   7.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   5.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   3.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   3.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   3.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   4.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   4.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   4.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   4.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   4.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   4.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   4.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   5.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   4.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   4.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.5s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.8s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.8s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.8s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.0s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.0s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.2s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.2s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.2s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.9s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   2.8s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2; total time=   1.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=3; total time=   2.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=4; total time=   2.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   2.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=3; total time=   1.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   2.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=4; total time=   2.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=5; total time=   3.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   1.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=3; total time=   2.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   2.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=5; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=4; total time=   2.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=3; total time=   1.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=5; total time=   2.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   1.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   1.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=4; total time=   1.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   1.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   1.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=5; total time=   1.7s
# Best Hyperparameters: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 2}

# %%
best_rf = grid_search.best_estimator_
y_preds_rf = best_rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_preds_rf))
print(classification_report(y_test, y_preds_rf))
# Out:
# Accuracy: 0.8209990087576771
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80     97875
#            1       0.77      0.91      0.84     97839
#
#     accuracy                           0.82    195714
#    macro avg       0.83      0.82      0.82    195714
# weighted avg       0.83      0.82      0.82    195714

# %% [markdown]
# ## Saving the best model

# %%
from joblib import dump
MODEL_NAME = "insurance-response-predictor.pkl"
dump(bg_clf, MODEL_NAME)
# Out:
# ['insurance-response-predictor.pkl']
